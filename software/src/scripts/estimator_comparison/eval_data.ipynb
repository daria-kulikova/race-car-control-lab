# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bagpy import bagreader
from eval_data import eval_data
from eval_data import plot_interagted_error

# %% [markdown]
# ### EKF

# %%
selection = ["ekf_lh", "ekf_lh_imu_yaw_rate_no_filt", "ekf_lh_imu_no_filt", "ekf_lh_we_no_filt", "ekf_lh_imu_we_no_filt", "ekf_lh_imu_yaw_rate_we_no_filt"]
Names = ['EKF + LH', 'EKF + LH + IMU YAW', 'EKF + LH + IMU', 'EKF + LH + WE', 'EKF + LH + WE + IMU', 'EKF + LH + WE + IMU YAW']

R_imu_yaw = None
R_imu = None
R_we = None
Threshold = None
plot_integrated_error = False

time_delay = 9 # MHE starts around 8 or 9s
run_time = 20 # Run goes to ca 30-32s, MHE goes crazy once bag finished.

eval_data("paper/20_03_2024", selection, Names, time_delay, run_time, plot_integrated_error, R_imu_yaw, R_imu, R_we, Threshold, with_std = False)
# Out:
# ekf_lh_imu_no_filt
# ekf_lh
# ekf_lh_imu_we_no_filt
# ekf_lh_imu_yaw_rate_no_filt
# ekf_lh_imu_yaw_rate_we_no_filt
# ekf_lh_we_no_filt
# <style type="text/css">
# #T_b905b_row0_col0, #T_b905b_row0_col3, #T_b905b_row0_col9, #T_b905b_row0_col10, #T_b905b_row0_col12, #T_b905b_row2_col1, #T_b905b_row2_col2, #T_b905b_row2_col10, #T_b905b_row2_col12, #T_b905b_row3_col6, #T_b905b_row4_col4, #T_b905b_row4_col5, #T_b905b_row4_col8, #T_b905b_row4_col10, #T_b905b_row4_col11, #T_b905b_row5_col7, #T_b905b_row5_col10, #T_b905b_row5_col12 {
#   font-weight: bold;
# }
# </style>
# <table id="T_b905b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b905b_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_b905b_level0_col1" class="col_heading level0 col1" >x</th>
#       <th id="T_b905b_level0_col2" class="col_heading level0 col2" >y</th>
#       <th id="T_b905b_level0_col3" class="col_heading level0 col3" >yaw</th>
# ...

# %% [markdown]
# ### EKF Filtered Data

# %%
selection = ["ekf_lh", "ekf_lh_imu_yaw_rate_filt", "ekf_lh_imu_filt", "ekf_lh_we_filt", "ekf_lh_imu_we_filt", "ekf_lh_imu_yaw_rate_we_filt"]
Names = ['EKF + LH', 'EKF + LH + IMU YAW(Filt)', 'EKF + LH + IMU (Filt)', 'EKF + LH + WE (Filt)', 'EKF + LH + WE + IMU (Filt)', 'EKF + LH + WE + IMU YAW (Filt)']

R_imu_yaw = None
R_imu = None
R_we = None
Threshold = None
plot_integrated_error = False

time_delay = 9 # MHE starts around 8 or 9s
run_time = 20 # Run goes to ca 30-32s, MHE goes crazy once bag finished.

eval_data("paper/20_03_2024", selection, Names, time_delay, run_time, plot_integrated_error, R_imu_yaw, R_imu, R_we, Threshold,  with_std = False)
# Out:
# ekf_lh_imu_we_filt
# ekf_lh_imu_yaw_rate_filt
# ekf_lh_we_filt
# ekf_lh
# ekf_lh_imu_yaw_rate_we_filt
# ekf_lh_imu_filt
# <style type="text/css">
# #T_350b5_row0_col0, #T_350b5_row0_col3, #T_350b5_row0_col9, #T_350b5_row0_col10, #T_350b5_row0_col12, #T_350b5_row1_col11, #T_350b5_row2_col1, #T_350b5_row2_col2, #T_350b5_row2_col11, #T_350b5_row3_col7, #T_350b5_row3_col11, #T_350b5_row4_col4, #T_350b5_row4_col5, #T_350b5_row4_col8, #T_350b5_row4_col11, #T_350b5_row5_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_350b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_350b5_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_350b5_level0_col1" class="col_heading level0 col1" >x</th>
#       <th id="T_350b5_level0_col2" class="col_heading level0 col2" >y</th>
#       <th id="T_350b5_level0_col3" class="col_heading level0 col3" >yaw</th>
#       <th id="T_350b5_level0_col4" class="col_heading level0 col4" >vx_w</th>
# ...

# %% [markdown]
# ### MHE

# %%
selection = ["mhe_lh","mhe_lh_imu_no_filt", "mhe_lh_imu_yaw_rate_no_filt", "mhe_lh_we_no_filt", "mhe_lh_imu_we_no_filt", 'mhe_lh_imu_yaw_rate_we_no_filt']
Names = ['MHE + LH', 'MHE + LH + IMU YAW', 'MHE + LH + IMU', 'MHE + LH + WE', 'MHE + LH + WE + IMU', 'MHE + LH + WE + IMU YAW']

R_imu_yaw = None
R_imu = None
R_we = None
Threshold = None
Q = None
plot_integrated_error = False

time_delay = 9 # MHE starts around 8 or 9s
run_time = 20 # Run goes to ca 30-32s, MHE goes crazy once bag finished.

# lh rejection threshold was 0.04

eval_data("paper/20_03_2024", selection, Names, time_delay, run_time, plot_integrated_error, R_imu_yaw, R_imu, R_we, Q, Threshold, with_std = False)
# Out:
# mhe_lh_imu_yaw_rate_no_filt
# mhe_lh
# mhe_lh_imu_yaw_rate_we_no_filt
# mhe_lh_imu_no_filt
# mhe_lh_we_no_filt
# mhe_lh_imu_we_no_filt
# <style type="text/css">
# #T_dcbfe_row0_col0, #T_dcbfe_row0_col9, #T_dcbfe_row0_col11, #T_dcbfe_row1_col1, #T_dcbfe_row1_col2, #T_dcbfe_row2_col6, #T_dcbfe_row4_col3, #T_dcbfe_row4_col4, #T_dcbfe_row4_col5, #T_dcbfe_row4_col7, #T_dcbfe_row4_col8, #T_dcbfe_row4_col10, #T_dcbfe_row4_col12 {
#   font-weight: bold;
# }
# </style>
# <table id="T_dcbfe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcbfe_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_dcbfe_level0_col1" class="col_heading level0 col1" >x</th>
#       <th id="T_dcbfe_level0_col2" class="col_heading level0 col2" >y</th>
#       <th id="T_dcbfe_level0_col3" class="col_heading level0 col3" >yaw</th>
#       <th id="T_dcbfe_level0_col4" class="col_heading level0 col4" >vx_w</th>
# ...

# %% [markdown]
# ### MHE Filtered Data

# %%
selection = ["mhe_lh","mhe_lh_imu_filt", "mhe_lh_imu_yaw_rate_filt", "mhe_lh_we_filt", "mhe_lh_imu_we_filt", 'mhe_lh_imu_yaw_rate_we_filt']
Names = ['MHE + LH', 'MHE + LH + IMU YAW (Filt)', 'MHE + LH + IMU (Filt)', 'MHE + LH + WE (Filt)', 'MHE + LH + WE + IMU (Filt)', 'MHE + LH + WE + IMU YAW (Filt)']

R_imu_yaw = None
R_imu = None
R_we = None
Threshold = None
Q = None
plot_integrated_error = False

time_delay = 9 # MHE starts around 8 or 9s
run_time = 20 # Run goes to ca 30-32s, MHE goes crazy once bag finished.

# lh rejection threshold was 0.04

# eval_data("paper/20_03_2024", selection, Names, time_delay, run_time, plot_integrated_error, R_imu_yaw, R_imu, R_we, Q, Threshold, with_std = False)

# %% [markdown]
# ### All

# %%
selection = ["ekf_lh", "mhe_lh", "ekf_lh_imu_yaw_rate_no_filt", "mhe_lh_imu_yaw_rate_no_filt","ekf_lh_imu_yaw_rate_filt","mhe_lh_imu_yaw_rate_filt", "ekf_lh_imu_no_filt", "mhe_lh_imu_no_filt", "ekf_lh_imu_filt", "mhe_lh_imu_filt","ekf_lh_we_no_filt", "mhe_lh_we_no_filt", "ekf_lh_we_filt", "mhe_lh_we_filt", "ekf_lh_imu_we_no_filt", "mhe_lh_imu_we_no_filt", "ekf_lh_imu_we_filt", "mhe_lh_imu_we_filt", "ekf_lh_imu_yaw_rate_we_no_filt", "mhe_lh_imu_yaw_rate_we_no_filt", "ekf_lh_imu_yaw_rate_we_filt", "mhe_lh_imu_yaw_rate_we_filt"]
Names = ["EKF + LH", "MHE + LH", "EKF + LH + IMU YAW", "MHE + LH + IMU YAW", "EKF + LH + IMU YAW (Filt)", "MHE + LH + IMU YAW (Filt)", "EKF + LH + IMU", "MHE + LH + IMU", "EKF + LH + IMU (Filt)", "MHE + LH + IMU (Filt)", "EKF + LH + WE", "MHE + LH + WE", "EKF + LH + WE (Filt)",  "MHE + LH + WE (Filt)", "EKF + LH + IMU + WE", "MHE + LH + IMU + WE", "EKF + LH + IMU + WE (Filt)", "MHE + LH + IMU + WE (Filt)", "EKF + LH + IMU YAW + WE", "MHE + LH + IMU YAW + WE", "EKF + LH + IMU YAW + WE (Filt)","MHE + LH + IMU YAW + WE (Filt)"]

R_imu_yaw = None
R_imu = None
R_we = None
Threshold = None
Q = None
plot_integrated_error = False

time_delay = 9 # MHE starts around 8 or 9s
run_time = 20 # Run goes to ca 30-32s, MHE goes crazy once bag finished.

# eval_data("paper/20_03_2024", selection, Names, time_delay, run_time, plot_integrated_error, R_imu_yaw, R_imu, R_we, Q, Threshold, with_std = False)

# %% [markdown]
# ### Plot Intergated Error

# %%
selection = ["mhe_lh","mhe_lh_imu_filt", "mhe_lh_imu_yaw_rate_filt", "mhe_lh_we_filt", "mhe_lh_imu_we_filt", 'mhe_lh_imu_yaw_rate_we_filt']
time_delay = 9 # MHE starts around 8 or 9s
run_time = 20 # Run goes to ca 30-32s, MHE goes crazy once bag finished.

# plot_interagted_error("paper/20_03_2024", selection, time_delay, run_time)
